# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import gzip
import os
import tempfile

import numpy
from six.moves import urllib
from six.moves import xrange 
import tensorflow as tf
from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets

# Loading MNIST data
mnist = read_data_sets('MNIST_data')
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#Defining convolutional neural network
import tensorflow.contrib.learn as learn
from sklearn import datasets, metrics
import numpy as np

layers = tf.contrib.layers
learn = tf.contrib.learn

def max_pool_2x2(tensor_in):
  return tf.nn.max_pool(
      tensor_in, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')


def conv_model(feature, target, mode):
  """2-layer convolution model."""
  # Convert the target to a one-hot tensor of shape (batch_size, 10) and
  # with a on-value of 1 for each one-hot vector of length 10.
  target = tf.one_hot(tf.cast(target, tf.int32), 10, 1, 0)

  # Reshape feature to 4d tensor with 2nd and 3rd dimensions being
  # image width and height final dimension being the number of color channels.
  feature = tf.reshape(feature, [-1, 28, 28, 1])

  # First conv layer will compute 32 features for each 5x5 patch
  with tf.variable_scope('conv_layer1'):
    h_conv1 = layers.convolution(
        feature, 32, kernel_size=[5, 5], activation_fn=tf.nn.relu)
    h_pool1 = max_pool_2x2(h_conv1)

  # Second conv layer will compute 64 features for each 5x5 patch.
  with tf.variable_scope('conv_layer2'):
    h_conv2 = layers.convolution(
        h_pool1, 64, kernel_size=[5, 5], activation_fn=tf.nn.relu)
    h_pool2 = max_pool_2x2(h_conv2)
    # reshape tensor into a batch of vectors
    h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])

  # Densely connected layer with 1024 neurons.
  h_fc1 = layers.dropout(
      layers.fully_connected(
          h_pool2_flat, 1024, activation_fn=tf.nn.relu),
      keep_prob=0.5,
      is_training=mode == tf.contrib.learn.ModeKeys.TRAIN)

  # Compute logits (1 per class) and compute loss.
  logits = layers.fully_connected(h_fc1, 10, activation_fn=None)
  loss = tf.contrib.losses.softmax_cross_entropy(logits, target)

  # Create a tensor for training op.
  train_op = layers.optimize_loss(
      loss,
      tf.contrib.framework.get_global_step(),
      optimizer='SGD',
      learning_rate=0.001)

  return tf.argmax(logits, 1), loss, train_op

# %%
def get_model_dir(name,erase):
    base_path = os.path.join(".","dnn")
    model_dir = os.path.join(base_path,name)
    os.makedirs(model_dir,exist_ok=True)
    if erase and len(model_dir)>4 and os.path.isdir(model_dir):
        shutil.rmtree(model_dir,ignore_errors=True) 
    return model_dir

# %%
#Training/Fitting CNN

import tensorflow as tf
import tensorflow.contrib.learn as learn
import time
import shutil

tf.logging.set_verbosity(tf.logging.INFO)

# Get/clear a directory to store the neural network to
model_dir = get_model_dir('mnist-cnn',True)

# %%
start_time = time.time()

classifier = learn.Estimator(model_fn=conv_model,model_dir=model_dir)
classifier.fit(mnist.train.images,
                 mnist.train.labels,
                 batch_size=100,
                 steps=20000)

elapsed_time = time.time() - start_time
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_environment': 'local', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f38c3d976a0>, '_task_id': 0, 'keep_checkpoint_every_n_hours': 10000, 'save_checkpoints_steps': None, '_num_ps_replicas': 0, 'tf_random_seed': None, 'keep_checkpoint_max': 5, 'save_summary_steps': 100, 'tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '
# INFO:tensorflow:global_step/sec: 2.33357
# INFO:tensorflow:step = 17901, loss = 0.242839
# INFO:tensorflow:global_step/sec: 2.33527
# INFO:tensorflow:step = 18001, loss = 0.183305
# INFO:tensorflow:global_step/sec: 2.32711
# INFO:tensorflow:step = 18101, loss = 0.0870069
# INFO:tensorflow:global_step/sec: 2.3321
# INFO:tensorflow:step = 18201, loss = 0.180706
# INFO:tensorflow:global_step/sec: 2.32373
# INFO:tensorflow:step = 18301, loss = 0.10644
# INFO:tensorflow:global_step/sec: 2.3274
# INFO:tensorflow:Saving checkpoints for 18306 into ./dnn/mnist-cnn/model.ckpt.
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# INFO:tensorflow:step = 18401, loss = 0.0825828
# INFO:tensorflow:global_step/sec: 2.31162
# INFO:tensorflow:step = 18501, loss = 0.135428
# INFO:tensorflow:global_step/sec: 2.31951
# INFO:tensorflow:step = 18601, loss = 0.173005
# INFO:tensorflow:global_step/sec: 2.31342
# INFO:tensorflow:step = 18701, loss = 0.142099
# INFO:tensorflow:global_step/sec: 2.32825
# INFO:tensorflow:step = 18801, loss = 0.138805
# INFO:tensorflow:global_step/sec: 1.98922
# INFO:tensorflow:step = 18901, loss = 0.0868768
# INFO:tensorflow:global_step/sec: 2.1227
# INFO:tensorflow:step = 19001, loss = 0.144648
# INFO:tensorflow:global_step/sec: 2.19719
# INFO:tensorflow:step = 19101, loss = 0.251398
# INFO:tensorflow:global_step/sec: 1.77861
# INFO:tensorflow:step = 19201, loss = 0.0836666
# INFO:tensorflow:global_step/sec: 1.99273
# INFO:tensorflow:step = 19301, loss = 0.133778
# INFO:tensorflow:global_step/sec: 1.87067
# INFO:tensorflow:step = 19401, loss = 0.139608
# INFO:tensorflow:global_step/sec: 1.83174
# INFO:tensorflow:step = 19501, loss = 0.112365
# INFO:tensorflow:global_step/sec: 1.88683
# INFO:tensorflow:Saving checkpoints for 19537 into ./dnn/mnist-cnn/model.ckpt.
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# INFO:tensorflow:step = 19601, loss = 0.147211
# INFO:tensorflow:global_step/sec: 2.00927
# INFO:tensorflow:step = 19701, loss = 0.155101
# INFO:tensorflow:global_step/sec: 1.68522
# INFO:tensorflow:step = 19801, loss = 0.221122
# INFO:tensorflow:global_step/sec: 1.9223
# INFO:tensorflow:step = 19901, loss = 0.172959
# INFO:tensorflow:global_step/sec: 1.99853
# INFO:tensorflow:Saving checkpoints for 20000 into ./dnn/mnist-cnn/model.ckpt.
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************
# INFO:tensorflow:Loss for final step: 0.0668687.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c65c9f06b579> in <module>()
#       8
#       9 elapsed_time = time.time() - start_time
# ---> 10 print("Elapsed time: {}".format(hms_string(elapsed_time)))
#
# NameError: name 'hms_string' is not defined

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

print("Elapsed time: {}".format(hms_string(elapsed_time)))
# Out:
# Elapsed time: 2:24:03.00

# %%
#Evaluate Accuracy

tf.logging.set_verbosity(tf.logging.ERROR)

score = metrics.accuracy_score(mnist.test.labels,
                                 list(classifier.predict(mnist.test.images)))
print('Accuracy: {0:f}'.format(score))
